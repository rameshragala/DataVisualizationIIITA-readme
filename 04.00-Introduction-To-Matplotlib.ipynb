# %% [markdown]
# # Introduction to Data Visualization using Matplotlib

# %% [markdown]
# Matplotlib is a multi-platform data visualization library built on NumPy arrays, and designed to work with the SciPy.
#
# Originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# Matplotlib package was born, with version 0.1 released in 2003.
#
# It received an early boost when it was adopted as the plotting package.
#
# One of it’s most important features is its ability to play well with many operating systems and graphics backends.

# %% [markdown]
# ### Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# we use ``plt`` interface most oftenly.

# %% [markdown]
# ### Setting Styles
#
# We will use the ``plt.style`` directive to choose appropriate aesthetic styles for figures.
# In this session, we are using``classic`` style.

# %%
plt.style.use('classic')

# %% [markdown]
# The available style sheets are based on the Matplotlib verion used by you.

# %%
plt.style.available[:25]
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid']

# %%
x = np.random.randn(1000)
plt.hist(x);
# use different style sheets and check the Figure

# %% [markdown]
# #### Plotting from a script
#
# If we are using Matplotlib from within a script, the function ``plt.show()`` is used to diplay the figure.
# ``plt.show()`` starts an event loop, looks for all currently active figure objects, and opens one or more interactive windows that display figure or figures.
#
# Example: *myplot.py* File:
#
# ```python
# # ------- file: myplot.py ------
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(0, 10, 100)
#
# plt.plot(x, np.sin(x))
# plt.plot(x, np.cos(x))
#
# plt.show()
# ```
#
# We can then run this script from the command-line prompt, which will result in a window opening with figure displayed:
#
# ```
# $ python myplot.py
# ```
#
# The ``plt.show()`` interacts with system's interactive graphical at backend.
#
# ``plt.show()`` command should be used *only once* per Python session, and is most often seen at the very end of the script.

# %%
# simple example
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# ### Saving Figures to File
#
# Matplotlib package provides an ability to save figures in a wide variety of formats.
#
# Saving a figure can be done using the ``savefig()`` command.

# %%
fig.savefig('my_figure10.png')

# %% [markdown]
# The above commands save the file in current working directory with file name as``my_figure.png``.

# %% [markdown]
# For confirm that it contains what we think it contains, let's use the IPython ``Image`` object to display the contents of this file:

# %%
from IPython.display import Image
Image('my_figure10.png')

# %% [markdown]
# In ``savefig()``, the file format is inferred from the extension of the given filename.
#
# Depending on what backends you have installed, many different file formats are available.
#
# The list of supported file types can be found by using the following method of the figure canvas object:

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## Two Interfaces:
#
# Matplotlib has dual interfaces:
#
# MATLAB-style state-based interface,
#
# object-oriented interface.

# %% [markdown]
# #### MATLAB-style Interface
#
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact.
#
# The MATLAB-style tools are contained in the pyplot (``plt``) interface.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# This interface is *stateful*: it keeps track of the "current" figure and axes, which are where all ``plt`` commands are applied.
# You can get a reference to these using the ``plt.gcf()`` (get current figure) and ``plt.gca()`` (get current axes) routines.

# %% [markdown]
# #### Object-oriented interface
#
# It is available for more complex situations, and for when we want more control over your figure.
# Rather than depending on some notion of an "active" figure or axes, in the object-oriented interface the plotting functions are *methods* of explicit ``Figure`` and ``Axes`` objects.
# To re-create the previous plot using this style of plotting, you might do the following:

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));
